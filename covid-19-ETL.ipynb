# %% [markdown]
# # Dependencies

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extract:
# ## Read COVID-19 CSV data into a dataframe

# %%
csv_file = "Resources/conposcovidloc.csv"
covid_data_df = pd.read_csv(csv_file, parse_dates = ['Accurate_Episode_Date'])

# %% [markdown]
# # Transform:
# ## Drop unnecessary columns

# %%
covid_columns = ['Row_ID', 'Accurate_Episode_Date', 'Age_Group', 'Client_Gender', 'Case_AcquisitionInfo',
                'Outcome1', 'Reporting_PHU', 'Reporting_PHU_City', 'Reporting_PHU_Postal_Code', 'Reporting_PHU_Latitude',
                'Reporting_PHU_Longitude']

covid_transformed_data_df = covid_data_df[covid_columns].copy()
covid_transformed_data_df.head()
# Out:
#    Row_ID Accurate_Episode_Date Age_Group Client_Gender Case_AcquisitionInfo  \
# 0       1            2020-01-22       50s        FEMALE       Travel-Related
# 1       2            2020-01-21       50s          MALE       Travel-Related
# 2       3            2020-01-24       20s        FEMALE       Travel-Related
# 3       4            2020-02-05       20s        FEMALE       Travel-Related
# 4       5            2020-02-16       60s        FEMALE       Travel-Related
#
#    Outcome1                 Reporting_PHU Reporting_PHU_City  \
# 0  Resolved         Toronto Public Health            Toronto
# 1  Resolved         Toronto Public Health            Toronto
# 2  Resolved  Middlesex-London Health Unit             London
# 3  Resolved         Toronto Public Health            Toronto
# 4  Resolved         Toronto Public Health            Toronto
#
#   Reporting_PHU_Postal_Code  Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 0                   M5B 1W2               43.656591               -79.379358
# 1                   M5B 1W2               43.656591               -79.379358
# 2                   N6A 5L7               42.981468               -81.254016
# 3                   M5B 1W2               43.656591               -79.379358
# 4                   M5B 1W2               43.656591               -79.379358

# %% [markdown]
# # Transform:
# # Rename columns

# %%
covid_transformed_data_df = covid_transformed_data_df.rename(columns={'Row_ID': 'ID', 
                                'Accurate_Episode_Date': 'Date',
                                'Client_Gender': 'Gender',
                                'Case_AcquisitionInfo': 'Case_Source',
                                'Outcome1': 'Outcome',
                                'Reporting_PHU': 'Health_Unit',
                                'Reporting_PHU_City': 'City',
                                'Reporting_PHU_Postal_Code': 'Postal_Code',
                                'Reporting_PHU_Latitude': 'Latitude',
                                'Reporting_PHU_Longitude': 'Longitude'})

covid_transformed_data_df.head()
# Out:
#    ID       Date Age_Group  Gender     Case_Source   Outcome  \
# 0   1 2020-01-22       50s  FEMALE  Travel-Related  Resolved
# 1   2 2020-01-21       50s    MALE  Travel-Related  Resolved
# 2   3 2020-01-24       20s  FEMALE  Travel-Related  Resolved
# 3   4 2020-02-05       20s  FEMALE  Travel-Related  Resolved
# 4   5 2020-02-16       60s  FEMALE  Travel-Related  Resolved
#
#                     Health_Unit     City Postal_Code   Latitude  Longitude
# 0         Toronto Public Health  Toronto     M5B 1W2  43.656591 -79.379358
# 1         Toronto Public Health  Toronto     M5B 1W2  43.656591 -79.379358
# 2  Middlesex-London Health Unit   London     N6A 5L7  42.981468 -81.254016
# 3         Toronto Public Health  Toronto     M5B 1W2  43.656591 -79.379358
# 4         Toronto Public Health  Toronto     M5B 1W2  43.656591 -79.379358

# %% [markdown]
# # Transform:
# ## rounding numeric values (Lat and Long)

# %%
covid_transformed_data_df['Latitude'] = covid_transformed_data_df['Latitude'].round()
covid_transformed_data_df['Longitude'] = covid_transformed_data_df['Longitude'].round()

covid_transformed_data_df.head()
# Out:
#    ID       Date Age_Group  Gender     Case_Source   Outcome  \
# 0   1 2020-01-22       50s  FEMALE  Travel-Related  Resolved
# 1   2 2020-01-21       50s    MALE  Travel-Related  Resolved
# 2   3 2020-01-24       20s  FEMALE  Travel-Related  Resolved
# 3   4 2020-02-05       20s  FEMALE  Travel-Related  Resolved
# 4   5 2020-02-16       60s  FEMALE  Travel-Related  Resolved
#
#                     Health_Unit     City Postal_Code  Latitude  Longitude
# 0         Toronto Public Health  Toronto     M5B 1W2      44.0      -79.0
# 1         Toronto Public Health  Toronto     M5B 1W2      44.0      -79.0
# 2  Middlesex-London Health Unit   London     N6A 5L7      43.0      -81.0
# 3         Toronto Public Health  Toronto     M5B 1W2      44.0      -79.0
# 4         Toronto Public Health  Toronto     M5B 1W2      44.0      -79.0

# %% [markdown]
# # Extract:
# ## Read second data source

# %%
csv_file = "Resources/Ministry_of_Health_Service_Provider_Locations.csv"
health_data_df = pd.read_csv(csv_file)
health_data_df.head()
# Out:
#            X          Y     OGF_ID MOH_SERVICE_PROVIDER_IDENT  \
# 0 -81.926396  45.978085  127908055                10000000106
# 1 -81.320617  48.476893  127908056                10000000107
# 2 -78.199754  43.970248  127908057                10000000108
# 3 -79.716322  43.482632  127908058                10000000109
# 4 -75.719439  45.393236  127908059                10000000110
#
#                     SERVICE_TYPE SERVICE_TYPE_DETAIL  \
# 0  Family Health Team - Contract                 NaN
# 1  Family Health Team - Contract                 NaN
# 2  Family Health Team - Contract                 NaN
# 3  Family Health Team - Contract                 NaN
# 4  Family Health Team - Contract                 NaN
#
#                                  ENGLISH_NAME FRENCH_NAME ENGLISH_NAME_ALT  \
# 0  Northeastern Manitoulin Family Health Team         NaN              NaN
# 1             Northern College (East End FHT)         NaN              NaN
# 2                          Northumberland FHT         NaN              NaN
# 3                   OakMed Family Health Team         NaN              NaN
# 4                Ottawa Hospital Academic FHT         NaN              NaN
#
#   FRENCH_NAME_ALT                 ADDRESS_LINE_1  \
# 0             NaN             15 Meredith Street
# 1             NaN  4715 Algonquin Boulevard East
# 2             NaN         1111 Elgin Street West
# 3             NaN         231 Oak Park Boulevard
# 4             NaN             210 Melrose Avenue
#
#                               ADDRESS_LINE_2 ADDRESS_DESCRIPTOR  \
# 0                      Postal Office Box 549                NaN
# 1                     Postal Office Box 3211                NaN
# 2  Postal Office Box 83, Northumberland Mall                NaN
# 3                                   Unit 110                NaN
# 4                                        NaN                NaN
#
#         COMMUNITY POSTAL_CODE  GEOMETRY_UPDATE_DATETIME  \
# 0  Little Current      P0P1K0                       NaN
# 1         Timmins      P4N8R6                       NaN
# 2         Cobourg      K9A4J7                       NaN
# 3        Oakville      L6H7S8                       NaN
# 4          Ottawa      K1Y4K7                       NaN
#
#          EFFECTIVE_DATETIME           SYSTEM_DATETIME  OBJECTID
# 0  2020-04-03T20:42:44.000Z  2020-04-03T20:42:44.000Z    754601
# 1  2020-04-03T20:42:44.000Z  2020-04-03T20:42:44.000Z    754602
# 2  2020-04-03T20:42:44.000Z  2020-04-03T20:42:44.000Z    754603
# 3  2020-04-03T20:42:44.000Z  2020-04-03T20:42:44.000Z    754604
# 4  2020-04-03T20:42:44.000Z  2020-04-03T20:42:44.000Z    754605

# %% [markdown]
# # Transform:
# ## Drop unnecessary columns

# %%
health_columns = ['X', 'Y', 'OGF_ID','SERVICE_TYPE', 'ENGLISH_NAME', 'COMMUNITY','POSTAL_CODE']

health_transformed_data_df = health_data_df[health_columns].copy()
health_transformed_data_df.head()
# Out:
#            X          Y     OGF_ID                   SERVICE_TYPE  \
# 0 -81.926396  45.978085  127908055  Family Health Team - Contract
# 1 -81.320617  48.476893  127908056  Family Health Team - Contract
# 2 -78.199754  43.970248  127908057  Family Health Team - Contract
# 3 -79.716322  43.482632  127908058  Family Health Team - Contract
# 4 -75.719439  45.393236  127908059  Family Health Team - Contract
#
#                                  ENGLISH_NAME       COMMUNITY POSTAL_CODE
# 0  Northeastern Manitoulin Family Health Team  Little Current      P0P1K0
# 1             Northern College (East End FHT)         Timmins      P4N8R6
# 2                          Northumberland FHT         Cobourg      K9A4J7
# 3                   OakMed Family Health Team        Oakville      L6H7S8
# 4                Ottawa Hospital Academic FHT          Ottawa      K1Y4K7

# %% [markdown]
# # Transform:
# ## Rename columns

# %%
health_transformed_data_df = health_transformed_data_df.rename(columns={'Y': 'Latitude', 
                                'X': 'Longitude',
                                'OGF_ID': 'Location_ID',
                                'SERVICE_TYPE':'Service_Type',
                                'ENGLISH_NAME': 'Name',
                                'COMMUNITY': 'Community',
                                'POSTAL_CODE': 'Postal_Code'})

health_transformed_data_df.head()
# Out:
#    Longitude   Latitude  Location_ID                   Service_Type  \
# 0 -81.926396  45.978085    127908055  Family Health Team - Contract
# 1 -81.320617  48.476893    127908056  Family Health Team - Contract
# 2 -78.199754  43.970248    127908057  Family Health Team - Contract
# 3 -79.716322  43.482632    127908058  Family Health Team - Contract
# 4 -75.719439  45.393236    127908059  Family Health Team - Contract
#
#                                          Name       Community Postal_Code
# 0  Northeastern Manitoulin Family Health Team  Little Current      P0P1K0
# 1             Northern College (East End FHT)         Timmins      P4N8R6
# 2                          Northumberland FHT         Cobourg      K9A4J7
# 3                   OakMed Family Health Team        Oakville      L6H7S8
# 4                Ottawa Hospital Academic FHT          Ottawa      K1Y4K7

# %% [markdown]
# # Transform:
# ## Drop unnecessary rows

# %%
service_types = ['Independent Health Facility', 'Retirement Home', 'Long-Term Care Home',
    'Senior Active Living Centre', 'Hospital - Corporation', 'AIDS Bureau',
    'Hospital - Site', 'Community Health Centre', 'Public Health Unit Office',
    "Children's Treatment Centre"]

health_columns = ['Latitude', 'Longitude', 'Location_ID','Service_Type', 'Name', 'Community','Postal_Code']

health_clean_data_df = pd.DataFrame(columns=health_columns)

for i in range(9):
    temp = health_transformed_data_df.loc[health_transformed_data_df['Service_Type'] == service_types[i], :] 
    health_clean_data_df = health_clean_data_df.append(temp)
    
health_clean_data_df.head()
# Out:
# /Users/ahmadmahroo/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#     Community   Latitude Location_ID  Longitude  \
# 298   Toronto  43.655559   127909184 -79.457512
# 299   Toronto  43.707537   127909185 -79.376238
# 300    Ottawa  45.420961   127909186 -75.700930
# 301   Toronto  43.662191   127909187 -79.366449
# 302   Toronto  43.759448   127909188 -79.224137
#
#                                         Name Postal_Code  \
# 298                  Choice in Health Clinic      M6P1A9
# 299                   The Morgentaler Clinic      M4S1V4
# 300                   The Morgentaler Clinic      K1P5N2
# 301               Cabbagetown Women's Clinic      M5A2G7
# 302  Markham - Lawrence X-Ray and Ultrasound      M1G1P4
#
#                     Service_Type
# 298  Independent Health Facility
# 299  Independent Health Facility
# 300  Independent Health Facility
# 301  Independent Health Facility
# 302  Independent Health Facility

# %% [markdown]
# # Transform:
# ## set index for dataframe and round lat and lng

# %%
health_clean_data_df.set_index("Location_ID", inplace=True)
health_clean_data_df['Latitude'] = health_clean_data_df['Latitude'].round()
health_clean_data_df['Longitude'] = health_clean_data_df['Longitude'].round()

health_clean_data_df.head()
# Out:
#             Community  Latitude  Longitude  \
# Location_ID
# 127909184     Toronto      44.0      -79.0
# 127909185     Toronto      44.0      -79.0
# 127909186      Ottawa      45.0      -76.0
# 127909187     Toronto      44.0      -79.0
# 127909188     Toronto      44.0      -79.0
#
#                                                 Name Postal_Code  \
# Location_ID
# 127909184                    Choice in Health Clinic      M6P1A9
# 127909185                     The Morgentaler Clinic      M4S1V4
# 127909186                     The Morgentaler Clinic      K1P5N2
# 127909187                 Cabbagetown Women's Clinic      M5A2G7
# 127909188    Markham - Lawrence X-Ray and Ultrasound      M1G1P4
#
#                             Service_Type
# Location_ID
# 127909184    Independent Health Facility
# 127909185    Independent Health Facility
# 127909186    Independent Health Facility
# 127909187    Independent Health Facility
# 127909188    Independent Health Facility

# %% [markdown]
# # Load:
# ## Create database connection

# %%
connection_string = "postgres:828516@localhost:5432/covid-19_db"
engine = create_engine(f'postgresql://{connection_string}')

covid_transformed_data_df.to_sql(name='covid_cases', con=engine, if_exists='replace', index=False)
health_clean_data_df.to_sql(name='health_service_providers', con=engine, if_exists='replace', index=False)
